# %% [markdown]
# # 05 — Motor Imagery Classification

# %% [markdown]
# ## Goal
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Data Preparation
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## CSP Feature Extraction
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Classical ML: LDA
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Classical ML: SVM
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Classical ML: Logistic Regression
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Deep Learning: EEGNet Architecture
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## EEGNet Training
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Cross-Subject Evaluation
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Results Comparison Table
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Confusion Matrices
#
# *To be implemented in upcoming chunk.*

# %% [markdown]
# ## Discussion
#
# *To be implemented in upcoming chunk.*
